# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []
city_names = []
fullset = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for c, lat_lng in enumerate(lat_lngs):
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    city = city.title()
    
    # If the city is unique, then add it to a our cities list
    if city not in cities and pd.notnull(city):
        cities.append(city)
        city_names.append(city)
        fullset.append(c)
        
# Reduce the lat/longs using the fullset list
lats = [lats[c] for c in fullset]
lngs = [lngs[c] for c in fullset]

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 616

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
        
    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q="
      
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url + city).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lon = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lon, 
                          "Max Temp (F)": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | Bhimunipatnam
# Processing Record 2 of Set 1 | Longyearbyen
# Processing Record 3 of Set 1 | Adamstown
# Processing Record 4 of Set 1 | Hawaiian Paradise Park
# Processing Record 5 of Set 1 | Port-Aux-Francais
# Processing Record 6 of Set 1 | Hammerfest
# Processing Record 7 of Set 1 | Wenchang
# Processing Record 8 of Set 1 | Edinburgh Of The Seven Seas
# Processing Record 9 of Set 1 | Selfoss
# Processing Record 10 of Set 1 | Zangguy
# City not found. Skipping...
# Processing Record 11 of Set 1 | Waitangi
# Processing Record 12 of Set 1 | Pisco
# Processing Record 13 of Set 1 | Nizhneangarsk
# Processing Record 14 of Set 1 | Albany
# Processing Record 15 of Set 1 | Petropavlovsk-Kamchatsky
# Processing Record 16 of Set 1 | Saipan
# Processing Record 17 of Set 1 | Bikenibeu Village
# Processing Record 18 of Set 1 | Askoy
# Processing Record 19 of Set 1 | Ateli Mandi
# Processing Record 20 of Set 1 | Bethel
# Processing Record 21 of Set 1 | Tralee
# Processing Record 22 of Set 1 | Ayaguz
# City not found. Skipping...
# Processing Record 23 of Set 1 | Olonkinbyen
# Processing Record 24 of Set 1 | Harpanahalli
# Processing Record 25 of Set 1 | West Island
# Processing Record 26 of Set 1 | Slave Lake
# Processing Record 27 of Set 1 | Blackmans Bay
# Processing Record 28 of Set 1 | Padang
# Processing Record 29 of Set 1 | Anloga
# Processing Record 30 of Set 1 | Gurupi
# Processing Record 31 of Set 1 | Grytviken
# Processing Record 32 of Set 1 | Agios Nikolaos
# Processing Record 33 of Set 1 | College
# Processing Record 34 of Set 1 | Hasaki
# Processing Record 35 of Set 1 | Zaozersk
# Processing Record 36 of Set 1 | Al Bahah
# Processing Record 37 of Set 1 | Udachny
# Processing Record 38 of Set 1 | Margaret River
# Processing Record 39 of Set 1 | Talnakh
# Processing Record 40 of Set 1 | Whitehorse
# Processing Record 41 of Set 1 | Lebu
# Processing Record 42 of Set 1 | Punta Arenas
# Processing Record 43 of Set 1 | Invercargill
# Processing Record 44 of Set 1 | Carnarvon
# Processing Record 45 of Set 1 | Smithers
# Processing Record 46 of Set 1 | Mount Gambier
# Processing Record 47 of Set 1 | Stanley
# Processing Record 48 of Set 1 | Iqaluit
# Processing Record 49 of Set 1 | Panaba
# Processing Record 50 of Set 1 | Nuuk
# Processing Record 0 of Set 2 | Qaisumah
# Processing Record 1 of Set 2 | Sarina
# Processing Record 2 of Set 2 | Manismata
# Processing Record 3 of Set 2 | Ponta Delgada
# Processing Record 4 of Set 2 | Codrington
# Processing Record 33 of Set 4 | Mokhsogollokh
# Processing Record 34 of Set 4 | Iskateley
# Processing Record 35 of Set 4 | Dursunbey
# Processing Record 36 of Set 4 | Conduaga
# Processing Record 37 of Set 4 | Nantucket
# Processing Record 38 of Set 4 | Ust'-Barguzin
# Processing Record 39 of Set 4 | Anadyr
# Processing Record 40 of Set 4 | Port Lincoln
# Processing Record 41 of Set 4 | Haiku-Pauwela
# Processing Record 42 of Set 4 | Ghat
# Processing Record 43 of Set 4 | Taiohae
# City not found. Skipping...
# Processing Record 44 of Set 4 | Enewetak
# Processing Record 45 of Set 4 | Takoradi
# Processing Record 46 of Set 4 | Kokhma
# Processing Record 47 of Set 4 | Siaton
# Processing Record 48 of Set 4 | Dila
# Processing Record 49 of Set 4 | Tianfu
# Processing Record 0 of Set 5 | Kendari
# Processing Record 1 of Set 5 | San Pedro Pochutla
# Processing Record 2 of Set 5 | Mary
# Processing Record 3 of Set 5 | Chepo
# Processing Record 4 of Set 5 | 'Ain El Bell
# Processing Record 5 of Set 5 | Shangqiu
# Processing Record 6 of Set 5 | Fukuecho
# Processing Record 7 of Set 5 | Tranovaho
# City not found. Skipping...
# Processing Record 8 of Set 5 | Kedougou
# Processing Record 9 of Set 5 | Kerteminde
# Processing Record 10 of Set 5 | Villa Berthet
# Processing Record 11 of Set 5 | Vengerovo
# Processing Record 12 of Set 5 | Bhag
# Processing Record 13 of Set 5 | Hithadhoo
# Processing Record 14 of Set 5 | Tuba City
# Processing Record 15 of Set 5 | Solnechnyy
# Processing Record 16 of Set 5 | Parry Sound
# Processing Record 17 of Set 5 | Vico Equense
# Processing Record 18 of Set 5 | Viedma
# Processing Record 19 of Set 5 | Hinton
# Processing Record 20 of Set 5 | Samarinda
# Processing Record 21 of Set 5 | Coahuayana De Hidalgo
# Processing Record 22 of Set 5 | Storkow
# Processing Record 23 of Set 5 | Dudinka
# Processing Record 24 of Set 5 | Nar'Yan-Mar
# Processing Record 25 of Set 5 | Rio Grande
# Processing Record 26 of Set 5 | Contamana
# Processing Record 27 of Set 5 | Saldanha
# Processing Record 28 of Set 5 | Santa Terezinha
# Processing Record 29 of Set 5 | Terme
# Processing Record 30 of Set 5 | Alesund
# Processing Record 31 of Set 5 | Jamestown
# Processing Record 32 of Set 5 | Jawala Mukhi
# Processing Record 33 of Set 5 | Wanning
# Processing Record 34 of Set 5 | Kerman
# Processing Record 35 of Set 5 | Vorgashor
# Processing Record 36 of Set 5 | Biloela
# Processing Record 37 of Set 5 | Aleksandrov Gay
# Processing Record 38 of Set 5 | Turpan
# Processing Record 39 of Set 5 | Cidreira
# Processing Record 40 of Set 5 | Berberati
# Processing Record 41 of Set 5 | Guarapari
# Processing Record 42 of Set 5 | Khandyga
# Processing Record 43 of Set 5 | Portland
# Processing Record 44 of Set 5 | Ketchikan
# Processing Record 45 of Set 5 | Alpena
# Processing Record 46 of Set 5 | Karratha
# Processing Record 47 of Set 5 | Bedesa
# Processing Record 48 of Set 5 | Nova Sintra
# Processing Record 49 of Set 5 | Mahina
# Processing Record 0 of Set 6 | Asuncion Nochixtlan
# Processing Record 1 of Set 6 | Shizunai-Furukawacho
# Processing Record 2 of Set 6 | Statesville
# Processing Record 3 of Set 6 | Floro
# Processing Record 4 of Set 6 | Acarau
# Processing Record 5 of Set 6 | Mount Isa
# Processing Record 6 of Set 6 | Varzea Da Palma
# Processing Record 7 of Set 6 | Rodolfo Sanchez Taboada
# Processing Record 8 of Set 6 | Uzgen
# Processing Record 9 of Set 6 | Brisas De Zicatela
# Processing Record 10 of Set 6 | Baddomalhi
# Processing Record 11 of Set 6 | Tamanrasset
# Processing Record 12 of Set 6 | Strezhevoy
# Processing Record 13 of Set 6 | Hotan
# Processing Record 14 of Set 6 | Afaahiti
# Processing Record 15 of Set 6 | San Felice Circeo
# Processing Record 16 of Set 6 | Tual
# Processing Record 17 of Set 6 | San Patricio
# Processing Record 18 of Set 6 | Prineville
# Processing Record 19 of Set 6 | Baiyin
# Processing Record 20 of Set 6 | Al Fqih Ben Calah
# Processing Record 21 of Set 6 | Medicine Hat
# Processing Record 22 of Set 6 | Kannapolis
# Processing Record 23 of Set 6 | Viqueque
# Processing Record 24 of Set 6 | Ilulissat
# Processing Record 25 of Set 6 | Lihue
# Processing Record 26 of Set 6 | Bubaque
# Processing Record 27 of Set 6 | Susuman
# Processing Record 28 of Set 6 | Vega De Alatorre
# Processing Record 29 of Set 6 | Sept-Iles
# Processing Record 30 of Set 6 | San Antonio De Pale
# Processing Record 31 of Set 6 | Vilyuysk
# Processing Record 32 of Set 6 | Copala
# Processing Record 33 of Set 6 | Orillia
# Processing Record 34 of Set 6 | Itoman
# Processing Record 35 of Set 6 | Francisco I. Madero
# Processing Record 36 of Set 6 | Crane
# Processing Record 37 of Set 6 | Dorado
# Processing Record 38 of Set 6 | Colonia
# Processing Record 39 of Set 6 | Kletskaya
# Processing Record 40 of Set 6 | Saint John
# Processing Record 41 of Set 6 | Fort St. John
# Processing Record 42 of Set 6 | Natal
# Processing Record 43 of Set 6 | Walvis Bay
# Processing Record 44 of Set 6 | Cill Airne
# Processing Record 45 of Set 6 | Baikonur
# Processing Record 46 of Set 6 | Newman
# Processing Record 47 of Set 6 | Praia Da Vitoria
# Processing Record 48 of Set 6 | Okhotsk
# Processing Record 49 of Set 6 | Clear Lake
# Processing Record 0 of Set 7 | Koneurgench
# City not found. Skipping...
# Processing Record 1 of Set 7 | Deming
# Processing Record 2 of Set 7 | Bandarbeyla
# Processing Record 3 of Set 7 | Laurinburg
# Processing Record 4 of Set 7 | Grand Falls-Windsor
# Processing Record 5 of Set 7 | Amos
# Processing Record 6 of Set 7 | Nikolayevsk-On-Amure
# Processing Record 7 of Set 7 | Donghai
# Processing Record 8 of Set 7 | Hami
# Processing Record 9 of Set 7 | Taibet
# City not found. Skipping...
# Processing Record 10 of Set 7 | Constitucion
# Processing Record 39 of Set 9 | Qurayyat
# Processing Record 40 of Set 9 | Bamboo Flat
# Processing Record 41 of Set 9 | Tres Palos
# Processing Record 42 of Set 9 | Rabo De Peixe
# Processing Record 43 of Set 9 | Midvagur
# Processing Record 44 of Set 9 | Al 'Alamayn
# City not found. Skipping...
# Processing Record 45 of Set 9 | Cortez
# Processing Record 46 of Set 9 | Ayora
# Processing Record 47 of Set 9 | Yung Shue Wan
# Processing Record 48 of Set 9 | Ancud
# Processing Record 49 of Set 9 | Dubbo
# Processing Record 0 of Set 10 | Tsementnyy
# Processing Record 1 of Set 10 | Jwaneng
# Processing Record 2 of Set 10 | Catalhoyuk
# Processing Record 3 of Set 10 | Izumo
# Processing Record 4 of Set 10 | Tasbuget
# City not found. Skipping...
# Processing Record 5 of Set 10 | Alice Springs
# Processing Record 6 of Set 10 | Dhemaji
# Processing Record 7 of Set 10 | Poli
# Processing Record 8 of Set 10 | Hidden Valley Lake
# Processing Record 9 of Set 10 | La Ronge
# Processing Record 10 of Set 10 | Polyarnyy
# Processing Record 11 of Set 10 | Tirumullaivasal
# Processing Record 12 of Set 10 | Zeya
# Processing Record 13 of Set 10 | Port Augusta
# Processing Record 14 of Set 10 | Buta
# Processing Record 15 of Set 10 | Tangalle
# Processing Record 16 of Set 10 | Cabugao
# Processing Record 17 of Set 10 | Olds
# Processing Record 18 of Set 10 | Tazovsky
# Processing Record 19 of Set 10 | Bejubang Dua
# City not found. Skipping...
# Processing Record 20 of Set 10 | Severo-Yeniseyskiy
# Processing Record 21 of Set 10 | Whangarei
# Processing Record 22 of Set 10 | San Julian
# Processing Record 23 of Set 10 | Hilo
# Processing Record 24 of Set 10 | Mgandu
# Processing Record 25 of Set 10 | Puerto San Carlos
# City not found. Skipping...
# Processing Record 26 of Set 10 | Alaghsas
# Processing Record 27 of Set 10 | Cherepanovo
# Processing Record 28 of Set 10 | Langzhong
# Processing Record 29 of Set 10 | Itai
# Processing Record 30 of Set 10 | Port-Vila
# Processing Record 31 of Set 10 | Ola
# Processing Record 32 of Set 10 | Gracemere
# Processing Record 33 of Set 10 | Katsuura
# Processing Record 34 of Set 10 | Kalsdorf Bei Graz
# Processing Record 35 of Set 10 | Kwang Binh
# Processing Record 36 of Set 10 | Kingston
# Processing Record 37 of Set 10 | Waiuku
# Processing Record 38 of Set 10 | Bushehr
# Processing Record 39 of Set 10 | Sinabang
# Processing Record 40 of Set 10 | Nema
# Processing Record 41 of Set 10 | Royan
# Processing Record 42 of Set 10 | Oroqen Zizhiqi
# Processing Record 43 of Set 10 | Siracusa
# Processing Record 44 of Set 10 | Tadine
# Processing Record 45 of Set 10 | Ulaangom
# Processing Record 46 of Set 10 | Port Macquarie
# Processing Record 47 of Set 10 | Volnovakha
# Processing Record 48 of Set 10 | Dharur
# Processing Record 49 of Set 10 | Meadow Lakes
# Processing Record 0 of Set 11 | Sofifi
# City not found. Skipping...
# Processing Record 1 of Set 11 | Kokofata
# City not found. Skipping...
# Processing Record 2 of Set 11 | Gizo
# Processing Record 3 of Set 11 | Big Bend
# Processing Record 4 of Set 11 | Ishimbay
# Processing Record 5 of Set 11 | Hohhot
# Processing Record 6 of Set 11 | Tahe
# Processing Record 7 of Set 11 | Praia
# Processing Record 8 of Set 11 | Adelia Maria
# Processing Record 9 of Set 11 | Comodoro Rivadavia
# Processing Record 10 of Set 11 | Sagaing
# Processing Record 11 of Set 11 | Paraty
# Processing Record 12 of Set 11 | Titao
# Processing Record 13 of Set 11 | Popondetta
# Processing Record 14 of Set 11 | Altai
# Processing Record 15 of Set 11 | Mejit
# Processing Record 16 of Set 11 | Big Spring
# Processing Record 17 of Set 11 | Sitka
# Processing Record 18 of Set 11 | Manokwari
# Processing Record 19 of Set 11 | Angaur State
# Processing Record 20 of Set 11 | Samalut
# Processing Record 21 of Set 11 | Arno
# Processing Record 22 of Set 11 | Suzun
# Processing Record 23 of Set 11 | Al Manaqil
# Processing Record 24 of Set 11 | Ntchisi
# Processing Record 25 of Set 11 | Batesville
# Processing Record 26 of Set 11 | St. Paul
# Processing Record 27 of Set 11 | Tilcara
# Processing Record 28 of Set 11 | Santo Antonio Do Amparo
# Processing Record 29 of Set 11 | Ankleshwar
# Processing Record 30 of Set 11 | Sao Miguel Do Tapuio
# Processing Record 31 of Set 11 | Road Town
# Processing Record 32 of Set 11 | Tarawa
# Processing Record 33 of Set 11 | Maiwut
# City not found. Skipping...
# Processing Record 34 of Set 11 | Moraleja
# Processing Record 35 of Set 11 | Glendive
# Processing Record 36 of Set 11 | El Nido
# Processing Record 37 of Set 11 | Tamandare
# Processing Record 38 of Set 11 | Pizarro
# Processing Record 39 of Set 11 | Margate
# Processing Record 40 of Set 11 | Illizi
# Processing Record 41 of Set 11 | Mitu
# Processing Record 42 of Set 11 | Geraldton
# Processing Record 43 of Set 11 | Cukai
# Processing Record 44 of Set 11 | Lazaro Cardenas
# Processing Record 45 of Set 11 | Taguatinga
# Processing Record 46 of Set 11 | Bengkulu
# Processing Record 47 of Set 11 | Lorengau
# Processing Record 48 of Set 11 | Thunder Bay
# Processing Record 49 of Set 11 | Posse
# Processing Record 0 of Set 12 | Dwarka
# Processing Record 1 of Set 12 | Khovd
# Processing Record 2 of Set 12 | Coronel Suarez
# Processing Record 3 of Set 12 | Zouerate
# Processing Record 4 of Set 12 | Ferkessedougou
# Processing Record 5 of Set 12 | Bagrationovsk
# Processing Record 6 of Set 12 | Ribeira Brava
# Processing Record 7 of Set 12 | Great Falls
# Processing Record 8 of Set 12 | Uhlingen-Birkendorf
# Processing Record 9 of Set 12 | Aripuana
# Processing Record 10 of Set 12 | Labytnangi
# Processing Record 11 of Set 12 | Melekeok Village
# Processing Record 12 of Set 12 | Velikiy Ustyug
# Processing Record 13 of Set 12 | Tabas
# Processing Record 14 of Set 12 | Cortland
# Processing Record 15 of Set 12 | Xilin Hot
# Processing Record 16 of Set 12 | At Taraf
# Processing Record 17 of Set 12 | San Jose Del Guaviare
# Processing Record 18 of Set 12 | Ouellah
# City not found. Skipping...
# Processing Record 19 of Set 12 | Palmer
# Processing Record 20 of Set 12 | Zhuangyuan
# Processing Record 21 of Set 12 | Cold Lake
# Processing Record 22 of Set 12 | Klaksvik
# Processing Record 23 of Set 12 | Changli
# Processing Record 24 of Set 12 | Glace Bay
# Processing Record 25 of Set 12 | Saurimo
# Processing Record 26 of Set 12 | Lerwick
# Processing Record 27 of Set 12 | Kavaratti
# Processing Record 28 of Set 12 | Comala
# Processing Record 29 of Set 12 | Wenling
# Processing Record 30 of Set 12 | Hagere Selam
# Processing Record 31 of Set 12 | Kichmengskiy Gorodok
# Processing Record 32 of Set 12 | Buala
# Processing Record 33 of Set 12 | Tibanbang
# Processing Record 34 of Set 12 | Malango
# Processing Record 35 of Set 12 | Kapiri Mposhi
# Processing Record 36 of Set 12 | Balboa
# Processing Record 37 of Set 12 | Sumbawanga
# Processing Record 38 of Set 12 | Laojunmiao
# Processing Record 39 of Set 12 | Antsiranana
# Processing Record 40 of Set 12 | Nadi
# Processing Record 41 of Set 12 | Kananga
# Processing Record 42 of Set 12 | Quibdo
# Processing Record 43 of Set 12 | Krasnyy Kut
# Processing Record 44 of Set 12 | Bulgan
# Processing Record 45 of Set 12 | Arraial Do Cabo
# Processing Record 46 of Set 12 | Ciudad Bolivar
# Processing Record 47 of Set 12 | Hobyo
# Processing Record 48 of Set 12 | Kirensk
# Processing Record 49 of Set 12 | Ta`U
# Processing Record 0 of Set 13 | Nichinan
# Processing Record 1 of Set 13 | Zahedan
# Processing Record 2 of Set 13 | Zastron
# Processing Record 3 of Set 13 | Huruta
# Processing Record 4 of Set 13 | Conde
# Processing Record 5 of Set 13 | Zhigalovo
# Processing Record 6 of Set 13 | Nizhneudinsk
# Processing Record 7 of Set 13 | Kailua-Kona
# Processing Record 8 of Set 13 | Motueka
# Processing Record 9 of Set 13 | Amahai
# Processing Record 10 of Set 13 | San Juan Bautista
# Processing Record 11 of Set 13 | Agadez
# Processing Record 12 of Set 13 | Glenfield Park
# Processing Record 13 of Set 13 | Aoulef
# Processing Record 14 of Set 13 | Rikaze
# Processing Record 15 of Set 13 | Puerto Madryn
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          592
# Lat           592
# Lng           592
# Max Temp      592
# Humidity      592
# Cloudiness    592
# Wind Speed    592
# Country       592
# Date          592
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Bhimunipatnam  17.8833   83.4333     94.51        64          10
# 1            Longyearbyen  78.2186   15.6401     39.04        70          75
# 2               Adamstown -25.0660 -130.1015     76.33        88          23
# 3  Hawaiian Paradise Park  19.5933 -154.9731     72.03        95         100
# 4       Port-Aux-Francais -49.3500   70.2167     44.82        98         100
#
#    Wind Speed Country        Date
# 0       21.14      IN  1684916979
# 1       11.50      SJ  1684916979
# 2       23.76      PN  1684916979
# 3        5.75      US  1684916979
# 4       11.48      TF  1684916980

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                 Bhimunipatnam  17.8833   83.4333     94.51        64
# 1                  Longyearbyen  78.2186   15.6401     39.04        70
# 2                     Adamstown -25.0660 -130.1015     76.33        88
# 3        Hawaiian Paradise Park  19.5933 -154.9731     72.03        95
# 4             Port-Aux-Francais -49.3500   70.2167     44.82        98
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                10       21.14      IN  1684916979
# 1                75       11.50      SJ  1684916979
# 2                23       23.76      PN  1684916979
# 3               100        5.75      US  1684916979
# 4               100       11.48      TF  1684916980

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df["Lat"].astype("float")
y_values = city_data_df["Max Temp"].astype("float")
plt.scatter(x_values,y_values, c='C0', s=25, edgecolors='0.0')

# Get the date from the dataframe
date_unix = city_data_df["Date"].iloc[1]
date = pd.to_datetime(date_unix, unit='s').strftime('%Y-%m-%d')

# Incorporate the other graph properties
plt.xlabel('Global Latitude of City')
plt.ylabel('Max Temperature (F)')
plt.title(f'Latitude vs. High Temperature ({date})')

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df["Lat"].astype("float")
y_values = city_data_df["Humidity"].astype("float")
plt.scatter(x_values,y_values, c='m', s=25, edgecolors='0.0')

# Incorporate the other graph properties
plt.xlabel('Global Latitude of City')
plt.ylabel('Humidity (%)')
plt.title(f'Latitude vs. Humidity ({date})')

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df["Lat"].astype("float")
y_values = city_data_df["Cloudiness"].astype("float")
plt.scatter(x_values,y_values, c='c', s=25, edgecolors='0.0')

# Incorporate the other graph properties
plt.xlabel('Global Latitude of City')
plt.ylabel('Cloud Cover (%)')
plt.title(f'Latitude vs. Cloudiness ({date})')

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. Wind Speed
x_values = city_data_df["Lat"].astype("float")
y_values = city_data_df["Wind Speed"].astype("float")
plt.scatter(x_values,y_values, c='C6', s=25, edgecolors='0.0')

# Incorporate the other graph properties
plt.xlabel('Global Latitude of City')
plt.ylabel('Wind Speed (f/s)')
plt.title(f'Latitude vs. Wind Speed ({date})')

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"]>=0),:]

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                 Bhimunipatnam  17.8833   83.4333     94.51        64
# 1                  Longyearbyen  78.2186   15.6401     39.04        70
# 3        Hawaiian Paradise Park  19.5933 -154.9731     72.03        95
# 5                    Hammerfest  70.6634   23.6821     48.65        81
# 6                      Wenchang  30.9040  118.4887     63.43        81
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                10       21.14      IN  1684916979
# 1                75       11.50      SJ  1684916979
# 3               100        5.75      US  1684916979
# 5                75       11.50      NO  1684916981
# 6                95        2.48      CN  1684916981

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"]<0),:]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2                          Adamstown -25.0660 -130.1015     76.33        88
# 4                  Port-Aux-Francais -49.3500   70.2167     44.82        98
# 7        Edinburgh Of The Seven Seas -37.0676  -12.3116     54.10        60
# 9                           Waitangi -43.9535 -176.5597     52.52        60
# 10                             Pisco -13.7000  -76.2167     69.85        83
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                23       23.76      PN  1684916979
# 4               100       11.48      TF  1684916980
# 7                14       16.87      SH  1684916981
# 9                 9       21.92      NZ  1684916982
# 10              100        8.05      PE  1684916982

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# Build scatter plot for latitude vs. temperature
x_values = northern_hemi_df["Lat"].astype("float")
y_values = northern_hemi_df["Max Temp"].astype("float")
plt.scatter(x_values,y_values, c='C0', s=25, edgecolors='0.0')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title("Latitude vs. High Temps in Northern Hemisphere")

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.4818233210185215

# %%
# Linear regression on Southern Hemisphere
# Build scatter plot for latitude vs. temperature
x_values = southern_hemi_df["Lat"].astype("float")
y_values = southern_hemi_df["Max Temp"].astype("float")
plt.scatter(x_values,y_values, c='C0', s=25, edgecolors='0.0')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title("Latitude vs. High Temps in Southern Hemisphere")

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.6688793267831656

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Build the scatter plots for latitude vs. humidity
x_values = northern_hemi_df["Lat"].astype("float")
y_values = northern_hemi_df["Humidity"].astype("float")
plt.scatter(x_values,y_values, c='m', s=25, edgecolors='0.0')

# Incorporate the other graph properties
plt.xlabel('Global Latitude of City')
plt.ylabel('Humidity (%)')
plt.title("Latitude vs. Humidity in Northern Hemisphere")

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.0019381243039076936

# %%
# Southern Hemisphere
# Build the scatter plots for latitude vs. humidity
x_values = southern_hemi_df["Lat"].astype("float")
y_values = southern_hemi_df["Humidity"].astype("float")
plt.scatter(x_values,y_values, c='m', s=25, edgecolors='0.0')

# Incorporate the other graph properties
plt.xlabel('Global Latitude of City')
plt.ylabel('Humidity (%)')
plt.title("Latitude vs. Humidity in Southern Hemisphere")

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.019427613096991796

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Build the scatter plots for latitude vs. cloudiness
x_values = northern_hemi_df["Lat"].astype("float")
y_values = northern_hemi_df["Cloudiness"].astype("float")
plt.scatter(x_values,y_values, c='c', s=25, edgecolors='0.0')

# Incorporate the other graph properties
plt.xlabel('Global Latitude of City')
plt.ylabel('Cloud Cover (%)')
plt.title("Latitude vs. Cloud Cover in Northern Hemisphere")

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.004921294170069339

# %%
# Southern Hemisphere
# Build the scatter plots for latitude vs. cloudiness
x_values = southern_hemi_df["Lat"].astype("float")
y_values = southern_hemi_df["Cloudiness"].astype("float")
plt.scatter(x_values,y_values, c='c', s=25, edgecolors='0.0')

# Incorporate the other graph properties
plt.xlabel('Global Latitude of City')
plt.ylabel('Cloud Cover (%)')
plt.title("Latitude vs. Cloud Cover in Southern Hemisphere")

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.04919203339452965

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Build the scatter plots for latitude vs. Wind Speed
x_values = northern_hemi_df["Lat"].astype("float")
y_values = northern_hemi_df["Wind Speed"].astype("float")
plt.scatter(x_values,y_values, c='C6', s=25, edgecolors='0.0')

# Incorporate the other graph properties
plt.xlabel('Global Latitude of City')
plt.ylabel('Wind Speed (f/s)')
plt.title("Latitude vs. Wind Speed in Northern Hemisphere")

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.026520897119052776

# %%
# Southern Hemisphere
# Build the scatter plots for latitude vs. Wind Speed
x_values = southern_hemi_df["Lat"].astype("float")
y_values = southern_hemi_df["Wind Speed"].astype("float")
plt.scatter(x_values,y_values, c='C6', s=25, edgecolors='0.0')

# Incorporate the other graph properties
plt.xlabel('Global Latitude of City')
plt.ylabel('Wind Speed (f/s)')
plt.title("Latitude vs. Wind Speed in Southern Hemisphere")

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Print r square value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.050904733324318004

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
